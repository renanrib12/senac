# %%
import pandas as pd
import numpy as np

# %%
df_anp = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep=';')
df_anp
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36898   159   10  2025  2025m10    35     4  Cachoeiras de Macacu  3300803
# 36899   165   10  2025  2025m10    33     5           Mangaratiba  3302601
# 36900   166   10  2025  2025m10    33     5        Angra dos Reis  3300100
# 36901   167   10  2025  2025m10    43     5                Paraty  3303807
# 36902   168   10  2025  2025m10    28     5             Rio Claro  3304409
#
# ...

# %%
df_rj_etanol = df_anp.loc[(df_anp['munic'] == 'RIO DE JANEIRO') & (df_anp['Produto'] == 'ETANOL')]
df_rj_etanol
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ribeiro.renan\Documents\senac\virtual\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Municipio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
df_rj_etanol['Valor de Venda'] = df_rj_etanol['Valor de Venda'].str.replace(',','.').astype(float)
# Out:
# C:\Users\ribeiro.renan\AppData\Local\Temp\ipykernel_30932\3668819183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rj_etanol['Valor de Venda'] = df_rj_etanol['Valor de Venda'].str.replace(',','.').astype(float)

# %%
media_bairro_rj = df_anp_rj.groupby('Bairro')['Valor de Venda'].mean().reset_index()
media_bairro_rj = media_bairro_rj.sort_values(by='Valor de Venda', ascending=False)
media_bairro_rj
# Out:
#                       Bairro  Valor de Venda
# 73                   COTIARA        7.145417
# 237             SANTA IZABEL        6.960000
# 156                     MURY        6.886731
# 162  NOVA ANGRA (CUNHAMBEBE)        6.856667
# 174     PARQUE DAS PALMEIRAS        6.801458
# ..                       ...             ...
# 157                  MUTONDO        5.181803
# 64                 COLUBANDE        5.103854
# 44                   CAMARAO        4.994000
# 216               RAUL VEIGA        4.978800
# 4                   ABOLIÇÃO        4.427500
#
# [285 rows x 2 columns]

# %%
array_valor_venda = np.array(media_bairro_rj['Valor de Venda'])

# %%
media = np.mean(array_valor_venda)
mediana = np.median(array_valor_venda)
q1 = np.quantile(array_valor_venda, 0.25)
q2 = np.quantile(array_valor_venda, 0.50)
q3 = np.quantile(array_valor_venda, 0.75)
iqr = q3 - q1
limite_s= q3 + 1.5*iqr
limite_i = q1 - 1.5*iqr

# %%
print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
print(f"O limite superior é {limite_s}")
print(f'O limite inferior é {limite_i}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(f'A média é {media}')
#       2 print(f'A mediana é {mediana}')
#       3 print(f'Primeiro quartil (Q1): {q1}')
#
# NameError: name 'media' is not defined

# %%
bairro_acima_q3 = media_bairro_rj.loc[media_bairro_rj['Valor de Venda'] > q3]
bairro_acima_q3
# Out:
#                       Bairro  Valor de Venda
# 73                   COTIARA        7.145417
# 237             SANTA IZABEL        6.960000
# 156                     MURY        6.886731
# 162  NOVA ANGRA (CUNHAMBEBE)        6.856667
# 174     PARQUE DAS PALMEIRAS        6.801458
# ..                       ...             ...
# 29                    BINGEN        6.061500
# 163             NOVA NITEROI        6.061275
# 67             CONSERVATORIA        6.050000
# 154                    MORIN        6.039000
# 30               BOA FORTUNA        6.036300
#
# [71 rows x 2 columns]

# %%
outlier_furto_celular = df_furto_celular.loc[df_furto+outlier_furto_celular['furto_celular'] > limite_s ]
